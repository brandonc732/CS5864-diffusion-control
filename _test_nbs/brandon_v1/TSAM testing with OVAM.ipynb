# %% [markdown]
# # Quick notebook for testing T-SAM with new optimal OVAM embeddings

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import torch

# %%
# general imports
import numpy as np
import pandas as pd
import torch

from diffusers import StableDiffusionPipeline

import os
import shutil

print(torch.version.cuda)
# Out:
# 12.1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# #### TSAM imports based on run python file

# %%
# the following code enables imports from the folders in the repository
# NOTE: this only affects the active kernel, not actual system path
import sys
from pathlib import Path

project_root = Path.cwd().parent.parent
sys.path.insert(0, str(project_root))

# %%
print(project_root)
# Out:
# C:\Users\brandon\Documents\CS 5864\CS5864-diffusion-control

# %%
import matplotlib.pyplot as plt
import torch
import os
import torch.nn.functional as F
from typing import List


from tsam.utils import (load_model,
                       save_image,
                       save_text_sa_avg,
                       get_token_ids,
                       LatentOptConfig)

import argparse
import yaml

# %% [markdown]
# $$ $$
#
# $$ $$
#
# $$ $$
#
# ## Model load in based on run file

# %%
from tsam.run import run_one_prompt

# %%
with open('../../tsam/configs/config.yaml','r') as f:
    config_dict = yaml.safe_load(f)
    
latent_opt_config = LatentOptConfig(**config_dict)


pipe = load_model(model_name='sd1_5x_2', device='cuda')
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!

# %% [markdown]
# $$ $$
#
# # Load optimized embedding files
#
# **NOTE:** The optimized embeddings for "male" are (2,768) since they also include the start token, so I index to take the second token, which should be the one we care about

# %%
opt_male = np.load('optimal_male_embedding.npy')[1]
opt_female = np.load('optimal_female_embedding.npy')[1]

# %%
opt_male.shape
# Out:
# (768,)

# %% [markdown]
# $$ $$
#
# ## Overview for creating optimized male and female prompts
#
# Simply:
# - encode a prompt: ____ "male"
# - replace the "male" embedding with the opt_male embedding
#
# This probably screws with the attention matrices within the encoder, but should be fine for us.
#
# $$ $$
#
# I'm going to do all this in the TSAM code with the following dictionary list input for a bias:
#
# [male_bias, female_bias]
#
# each dictionary has:
# - word : male/female
# - opt_embedding : numpy (768,)
#
# we will also take in an argument of a bias prompt in the form "a photo of a {}"
#
#
# $$ $$
#
# $$ $$
#
# $$ $$

# %%
# do run_one_prompt code with reduced version
def bias_reduced_generation(main_prompt, occupation_info, bias_prompt_form, bias_info, num_inference_steps=50):

    pipe.text_encoder.to("cuda")
        
    # sd 1.5 option
    pipe.attn_fetch_x.set_processor(unet = pipe.unet)
    
    steps_to_save_attention_maps = list(range(num_inference_steps))
    
    max_iter_to_alter = latent_opt_config.max_iter_to_alter
    iterative_refinement_steps = latent_opt_config.iterative_refinement_steps
    
    if not latent_opt_config.update_latent:
        max_iter_to_alter = 0
        iterative_refinement_steps = []
    
    image, all_maps = pipe.bias_reduced_call(
        prompt=main_prompt,
        generator=torch.Generator("cuda").manual_seed(1234),
        num_inference_steps=num_inference_steps,
        max_iter_to_alter=max_iter_to_alter,
        steps_to_save_attention_maps=steps_to_save_attention_maps,
        latent_opt_config = latent_opt_config,

        bias_prompt_form=bias_prompt_form,
        bias_info=bias_info,
        occupation_info=occupation_info,
    )

    return image, all_maps

# %% [markdown]
# $$ $$
#
# $$ $$
#
# ## Bias generation setup
#
#
# Current attributes used from latent_opt_config:
# - show_first_bias_map
#     - Whether to display UNet cross attentions at beginning of bias reduction iterations
# - show_last_bias_map
#     - Whether to display UNet cross attentions after bias reduction iterations
# - bias_refinement_steps
#     - List of generation steps to run bias reduction iteration loop
# - bias_loss_threshold
#     - float loss threshold for when to break bias loss iteration loop
#     -
#
#
# $$ $$
# latent_opt_config.bias_loss_function_details is a dictionary with the following optional keys
#    - display: all or one
#        - whether to display all UNet cross attention layers or just the ones being used for loss function
#    - separate_scales: True or False, default False
#        - whether the groups of displayed cross attention maps should use the same color scale
#    - max_cnt: int, default 30
#        - maximum interation count for bias loss iterations
#    - block_class: None, 'CrossAttnUpBlock2D' or 'CrossAttnDownBlock2D'
#        - block class to grab cross attentions from
#        - None defaults to T-SAM default of using both bottle neck layers
#        - **NOTE:** I haven't implemented being able to choose multiple UNet blocks or interpolating between them
#    - total_map_size: 16\*16, 32\*32, 64\*64
#        - total map size of desired cross attention layer (s*s)
#        - not required if block_class is None

# %%
# disable T-SAM iterative function
latent_opt_config.iterative_refinement_steps = []

# bias map display settings
latent_opt_config.show_first_bias_map = True
latent_opt_config.show_last_bias_map = False

latent_opt_config.bias_refinement_steps = [0, 10, 20, 30, 40]

latent_opt_config.bias_loss_function_details = {'display' : 'one',                      # 'all' or default of one
                                                'separate_scales': True,                # True or default of None/False
                                                'block_class': 'CrossAttnUpBlock2D',    # None, 'CrossAttnUpBlock2D' or 'CrossAttnDownBlock2D'
                                                'total_map_size': 64*64}                #  None, 16*16, 32*32, or 64*64
latent_opt_config.bias_loss_threshold = 0.01


main_prompt = "A photo of the face of a nurse"

occupation_info = {'word' : 'nurse'}

bias_prompt_form = "A photo of a {}"
bias_info = [{'word' : 'male',   'opt_embedding' : np.load('optimal_male_embedding.npy')[1]},
             {'word' : 'female', 'opt_embedding' : np.load('optimal_female_embedding.npy')[1]}]

image, attention_maps = bias_reduced_generation(main_prompt, occupation_info, bias_prompt_form, bias_info, num_inference_steps=50)
# Out:
# num_warmup_steps: 1
#   0%|          | 0/50 [00:00<?, ?it/s]
# C:\Users\brandon\anaconda3\envs\tsam\lib\site-packages\torch\functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3596.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# T-SAM attn loss: 1.7890625
# Starting bias iterative refinement for step: 0
# C:\Users\brandon\Documents\CS 5864\CS5864-diffusion-control\tsam\models\sd1_5\pipeline_stable_diffusion_x_2.py:2610: UserWarning: Bias loss function has not been implemented yet. Setting to 0 by default
#   warnings.warn("Bias loss function has not been implemented yet. Setting to 0 by default")
# bias loss breaking from loss < 0.01
# updated latent (step 0)
# T-SAM attn loss: 1.78515625
# updated latent (step 1)
# T-SAM attn loss: 1.787109375
# updated latent (step 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 25
#      21 bias_prompt_form = "A photo of a {}"
#      22 bias_info = [{'word' : 'male',   'opt_embedding' : np.load('optimal_male_embedding.npy')[1]},
#      23              {'word' : 'female', 'opt_embedding' : np.load('optimal_female_embedding.npy')[1]}]
# ---> 25 image, attention_maps = bias_reduced_generation(main_prompt, occupation_info, bias_prompt_form, bias_info, num_inference_steps=50)
#
# Cell In[12], line 18, in bias_reduced_generation(main_prompt, occupation_info, bias_prompt_form, bias_info, num_inference_steps)
#      15     max_iter_to_alter = 0
#      16     iterative_refinement_steps = []
# ---> 18 image, all_maps = pipe.bias_reduced_call(
#      19     prompt=main_prompt,
#      20     generator=torch.Generator("cuda").manual_seed(1234),
#      21     num_inference_steps=num_inference_steps,
#      22     max_iter_to_alter=max_iter_to_alter,
#      23     steps_to_save_attention_maps=steps_to_save_attention_maps,
#      24     latent_opt_config = latent_opt_config,
#      25
#      26     bias_prompt_form=bias_prompt_form,
#      27     bias_info=bias_info,
#      28     occupation_info=occupation_info,
#      29 )
#      31 return image, all_maps
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~\Documents\CS 5864\CS5864-diffusion-control\tsam\models\sd1_5\pipeline_stable_diffusion_x_2.py:2406, in StableDiffusionPipelineX_2.bias_reduced_call(self, prompt, num_inference_steps, generator, max_iter_to_alter, steps_to_save_attention_maps, latent_opt_config, bias_prompt_form, bias_info, occupation_info)
#    2401 latent_model_input = self.scheduler.scale_model_input(
#    2402     latent_model_input, t
#    2403 )
#    2405 # predict the noise residual
# -> 2406 noise_pred = self.unet(
#    2407     latent_model_input,
#    2408     t,
#    2409     encoder_hidden_states=prompt_embeds,
#    2410     cross_attention_kwargs=None,
#    2411 ).sample
#    2413 # perform guidance
#    2414 if self.do_classifier_free_guidance:
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\tsam\lib\site-packages\diffusers\models\unets\unet_2d_condition.py:1280, in UNet2DConditionModel.forward(self, sample, timestep, encoder_hidden_states, class_labels, timestep_cond, attention_mask, cross_attention_kwargs, added_cond_kwargs, down_block_additional_residuals, mid_block_additional_residual, down_intrablock_additional_residuals, encoder_attention_mask, return_dict)
#    1277     upsample_size = down_block_res_samples[-1].shape[2:]
#    1279 if hasattr(upsample_block, "has_cross_attention") and upsample_block.has_cross_attention:
# -> 1280     sample = upsample_block(
#    1281         hidden_states=sample,
#    1282         temb=emb,
#    1283         res_hidden_states_tuple=res_samples,
#    1284         encoder_hidden_states=encoder_hidden_states,
#    1285         cross_attention_kwargs=cross_attention_kwargs,
#    1286         upsample_size=upsample_size,
#    1287         attention_mask=attention_mask,
#    1288         encoder_attention_mask=encoder_attention_mask,
#    1289     )
#    1290 else:
#    1291     sample = upsample_block(
#    1292         hidden_states=sample,
#    1293         temb=emb,
#    1294         res_hidden_states_tuple=res_samples,
#    1295         upsample_size=upsample_size,
#    1296     )
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\tsam\lib\site-packages\diffusers\models\unets\unet_2d_blocks.py:2469, in CrossAttnUpBlock2D.forward(self, hidden_states, res_hidden_states_tuple, temb, encoder_hidden_states, cross_attention_kwargs, upsample_size, attention_mask, encoder_attention_mask)
#    2467 if self.upsamplers is not None:
#    2468     for upsampler in self.upsamplers:
# -> 2469         hidden_states = upsampler(hidden_states, upsample_size)
#    2471 return hidden_states
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\tsam\lib\site-packages\diffusers\models\upsampling.py:188, in Upsample2D.forward(self, hidden_states, output_size, *args, **kwargs)
#     186 if self.use_conv:
#     187     if self.name == "conv":
# --> 188         hidden_states = self.conv(hidden_states)
#     189     else:
#     190         hidden_states = self.Conv2d_0(hidden_states)
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\anaconda3\envs\tsam\lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
